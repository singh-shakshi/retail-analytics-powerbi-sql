# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\Shakshi\Desktop\retail project portofolio\retail_sales_50k.csv"
)

df.head()
# Out:
#      order_id  order_date  month_num month_name quarter region   store_id  \
# 0  ORD-100001  2023-05-21          5        May      Q2  South  STR-SO-07
# 1  ORD-100002  2023-02-17          2   February      Q1  North  STR-NO-04
# 2  ORD-100003  2023-05-23          5        May      Q2   East  STR-EA-03
# 3  ORD-100004  2023-02-22          2   February      Q1  North  STR-NO-08
# 4  ORD-100005  2023-07-13          7       July      Q3   East  STR-EA-02
#
#   customer_id   category sub_category          sku  quantity  unit_price  \
# 0  CUST-87397     Sports      Cricket  SKU-CRI-001         5     2110.16
# 1  CUST-64987     Sports      Cricket  SKU-CRI-001        17     1905.38
# 2  CUST-46421   Clothing     Footwear  SKU-FTW-003         1     4104.32
# 3  CUST-15695  Groceries       Snacks  SKU-SNK-002         4       73.59
# 4  CUST-35203     Sports     Swimming  SKU-SWM-001        10      814.64
#
#    unit_cost  discount_pct   revenue      cogs   profit payment_method  \
# ...

# %%
df.shape
# Out:
# (52000, 20)

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'month_num', 'month_name', 'quarter',
#        'region', 'store_id', 'customer_id', 'category', 'sub_category', 'sku',
#        'quantity', 'unit_price', 'unit_cost', 'discount_pct', 'revenue',
#        'cogs', 'profit', 'payment_method', 'sales_channel'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52000 entries, 0 to 51999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        52000 non-null  object
#  1   order_date      52000 non-null  object
#  2   month_num       52000 non-null  int64
#  3   month_name      52000 non-null  object
#  4   quarter         52000 non-null  object
#  5   region          52000 non-null  object
#  6   store_id        52000 non-null  object
#  7   customer_id     52000 non-null  object
#  8   category        52000 non-null  object
#  9   sub_category    52000 non-null  object
#  10  sku             52000 non-null  object
#  11  quantity        52000 non-null  int64
#  12  unit_price      52000 non-null  float64
#  13  unit_cost       52000 non-null  float64
#  14  discount_pct    52000 non-null  int64
#  15  revenue         52000 non-null  float64
#  16  cogs            52000 non-null  float64
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52000 entries, 0 to 51999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        52000 non-null  object
#  1   order_date      52000 non-null  datetime64[ns]
#  2   month_num       52000 non-null  int64
#  3   month_name      52000 non-null  object
#  4   quarter         52000 non-null  object
#  5   region          52000 non-null  object
#  6   store_id        52000 non-null  object
#  7   customer_id     52000 non-null  object
#  8   category        52000 non-null  object
#  9   sub_category    52000 non-null  object
#  10  sku             52000 non-null  object
#  11  quantity        52000 non-null  int64
#  12  unit_price      52000 non-null  float64
#  13  unit_cost       52000 non-null  float64
#  14  discount_pct    52000 non-null  int64
#  15  revenue         52000 non-null  float64
#  16  cogs            52000 non-null  float64
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          order_id order_date  month_num month_name quarter   region  \
# 0      ORD-100001 2023-05-21          5        May      Q2    South
# 1      ORD-100002 2023-02-17          2   February      Q1    North
# 2      ORD-100003 2023-05-23          5        May      Q2     East
# 3      ORD-100004 2023-02-22          2   February      Q1    North
# 4      ORD-100005 2023-07-13          7       July      Q3     East
# ...           ...        ...        ...        ...     ...      ...
# 51995  ORD-151996 2023-06-04          6       June      Q2    South
# 51996  ORD-151997 2023-06-17          6       June      Q2  Central
# 51997  ORD-151998 2023-06-13          6       June      Q2    North
# 51998  ORD-151999 2023-01-01          1    January      Q1    North
# 51999  ORD-152000 2023-08-19          8     August      Q3    South
#
#         store_id customer_id     category sub_category          sku  quantity  \
# ...

# %%
df.describe(include='all')
# Out:
#           order_id                     order_date     month_num month_name  \
# count        52000                          52000  52000.000000      52000
# unique       52000                            NaN           NaN         12
# top     ORD-100001                            NaN           NaN        May
# freq             1                            NaN           NaN       4477
# mean           NaN  2023-07-01 21:21:02.769231104      6.521769        NaN
# min            NaN            2023-01-01 00:00:00      1.000000        NaN
# 25%            NaN            2023-04-02 00:00:00      4.000000        NaN
# 50%            NaN            2023-07-01 00:00:00      7.000000        NaN
# 75%            NaN            2023-10-01 00:00:00     10.000000        NaN
# max            NaN            2023-12-31 00:00:00     12.000000        NaN
# std            NaN                            NaN      3.445301        NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# month_num         0
# month_name        0
# quarter           0
# region            0
# store_id          0
# customer_id       0
# category          0
# sub_category      0
# sku               0
# quantity          0
# unit_price        0
# unit_cost         0
# discount_pct      0
# revenue           0
# cogs              0
# profit            0
# payment_method    0
# sales_channel     0
# dtype: int64

# %%
df[['revenue','profit','quantity','unit_price','unit_cost']].describe()
# Out:
#             revenue         profit      quantity    unit_price     unit_cost
# count  5.200000e+04   52000.000000  52000.000000  52000.000000  52000.000000
# mean   1.262389e+05   38498.382494     10.465365  12992.488801   8384.602377
# std    2.241639e+05   77742.979182      5.761068  19120.448711  12926.019427
# min    2.742000e+01 -216998.200000      1.000000     30.090000     13.790000
# 25%    6.003275e+03    1616.207500      5.000000    933.650000    572.702500
# 50%    2.763123e+04    7677.795000     10.000000   3160.220000   1967.430000
# 75%    1.191828e+05   32331.045000     15.000000  18534.065000  11497.117500
# max    1.598605e+06  868670.600000     20.000000  79990.290000  75859.260000

# %%
df.to_csv("cleaned_retail_sales.csv", index=False)

# %%
df.shape
# Out:
# (52000, 20)

# %%
df.to_csv(
    r"C:\Users\Shakshi\Desktop\retail project portofolio\cleaned_retail_sales.csv",
    index=False
)

# %%
import os

os.path.exists(
    r"C:\Users\Shakshi\Desktop\retail project portofolio\cleaned_retail_sales.csv"
)
# Out:
# True
